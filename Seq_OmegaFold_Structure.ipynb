# %%
import os, time, datetime

# %%
# %cd E:\OmegaFold-main
# Out:
# E:\OmegaFold-main
# C:\Users\admin\.conda\envs\omegafold\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
file_path = os.listdir(r'F:\Reaction_Model')

# %%
for file in file_path:
    fasta_path = os.path.join(r'F:\Reaction_Model',file)
    fasta_input = os.path.join(fasta_path,r'gent_seq\generated_samples_string.fasta')
    output_path = os.path.join(fasta_path,r'gent_seq\OmegaFold')
    # os.makedirs(output_path, exist_ok=True)
    print(f"[{datetime.datetime.now():%F %T}] START  {file}")
    # !conda run -n omegafold python -m omegafold "{fasta_input}" "{output_path}"
    print(f"[{datetime.datetime.now():%F %T}] DONE   {file}\n")
# Out:
# ^C
